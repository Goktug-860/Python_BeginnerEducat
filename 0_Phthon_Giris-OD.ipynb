# %% [markdown]
# #Çalıştığım Sunucu Billgileri

# %%
# !nvidia-smi
# Out:
# Sat Dec 14 10:10:10 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# #Python İlk Kod
# Python'a giriş dersinde ilk olarak bilgisayara yazı yazdırıyoruz!

# %%
print ("HELLO WORD!")
# Out:
# HELLO WORD!

# %%
print (2+8)
# Out:
# 10

# %%
print (str(2)+""+str(8))
# Out:
# 28

# %% [markdown]
# **String**:Metin değişkenleri anlamına gelir.""(çift tırnak) işaretiarasına yazılır.Sayıları metne dönüştürürken str(sayi)içine yazarız.
#
# **Integer:**Sayı değişkenlerianlamına gelir. Sadece sayının kendisi yazılır. Sayıya çevirmek için int(sayi) yazarız.

# %%
print(len("MATEMATİK"))
# Out:
# 9

# %% [markdown]
# Not-1: Sayılarımetinlere çevirebilirim ançakmetinleri sayıya çeviremem.
#
# Not-2: Metinlerin harf sayısının (uzunluğunu) öğrenerim.
#
# len():Parantez içine çift tirnakla  bir yazı yazı yazarsam bana harf sayısını
# verir.

# %%
print (23+9)
print (23-9)
print (23*9)
print (23/9)
# Out:
# 32
# 14
# 207
# 2.5555555555555554

# %%
print((23+9),(23-9),(23*9),(23/9))
print((23+9)+(23-9)+(23*9)+(23/9))
# Out:
# 32 14 207 2.5555555555555554
# 255.55555555555554

# %%
print ("MERHABA","ÜPER DAYIYA HOŞGELDİN")
print ("Size nası"+"yardım edebilirim?")
# Out:
# MERHABA ÜPER DAYIYA HOŞGELDİN
# Size nasıyardım edebilirim?

# %%
print("İyilik Büyüsü menüsü:\n"+"kuru fasulcenin fagaları\n")
# Out:
# İyilik Büyüsü menüsü:
# kuru fasulcenin fagaları
